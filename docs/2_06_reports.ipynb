# %% [markdown]
#  # Reports #
#
#  After constructing a Synthorus system, different reports are available on the system. In general, the reports are created by reading model definitions files and the reports are written to the "reports" subdirectory in the directory.
#
# Some report can be made by the `make_model_definition_files` script and some reports can be made by running a script after the model definition files are generated.
#
# The following table summarises the reports and how they may be generated.
#
# | report                      | file name                | make_model_definition_files | manual script function   |
# |:----------------------------|:-------------------------|:----------------------------|:-------------------------|
# | detailed cross-table report | crosstabs.csv            | ✓                           | ✗                        |
# | model specification report  | report_on_model_spec.txt | ✓                           | `make_model_spec_report` |
# | privacy report              | report_on_privacy.txt    | ✓                           | `make_privacy_report`    |
# | utility report              | report_on_utility.txt    | ✗                           | `make_utility_report`    |
# | detailed utility results    | utility_results.csv      | ✗                           | `make_utility_report`    |

# %% [markdown]
# The following code uses `make_model_definition_files`  to create a Synthorus system, but only creates the cross-table report.
#
# Note that a demo output directory is used but not in a `with` context. This is so we can have a running example.

# %%
from synthorus_demos.utils.file_helper import print_file_tree
from synthorus_demos.utils.file_helper import cat
from synthorus.utils.print_function import NO_LOG
from synthorus.workflows.make_model_definition_files import make_model_definition_files
from synthorus_demos.demo_files import SPEC_FILES
from synthorus.spec_file.interpret_spec_file import load_spec_file
from synthorus.model.model_spec import ModelSpec
from synthorus_demos.utils.output_directory import output_directory


# Create a managed demo output directory for the output model definition files.
model_definition_dir = output_directory('demo_reports')

model_spec: ModelSpec = load_spec_file(SPEC_FILES / 'spec_simple_pjm.py')
make_model_definition_files(
    model_spec,
    model_definition_dir,
    make_crosstab_report=True,
    make_privacy_report=False,
    make_model_spec_report=False,
    overwrite=True,
    log=NO_LOG,
)

# Show what files were created
print('-------------------------------------------')
print_file_tree(model_definition_dir)
print('-------------------------------------------')
# Out:
# -------------------------------------------
# demo_reports/
#   clean_cross_tables/
#     _event_duration.pkl
#     _event_duration_since_last.pkl
#     _event_type.pkl
#     _patient_age.pkl
#   model_index.json
#   model_spec.json
#   noisy_cross_tables/
#     _event_duration.pkl
#     _event_duration_since_last.pkl
#     _event_type.pkl
#     _patient_age.pkl
#   pgms/
#     event.py
#     patient.py
#   reports/
#     crosstabs.csv
#   simulator_spec.json
# -------------------------------------------

# %% [markdown]
# ## Cross-table report ##
#
# Here is the resulting cross-table report. In this example we use Pandas to format the CSV file for display.

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

pd.read_csv(model_definition_dir / 'reports' / 'crosstabs.csv')
# Out:
#                   Cross-table                Data-source  Number-of-rvs  \
# 0                _patient_age    patient_age__event_type              1
# 1                 _event_type    patient_age__event_type              1
# 2             _event_duration             event_duration              1
# 3  _event_duration_since_last  event_duration_since_last              1
#
#                            RVs  State-space-size  Number-of-rows  \
# 0                'patient_age'                 3               3
# 1                 'event_type'                 4               4
# 2             'event_duration'                 9               9
# 3  'event_duration_since_last'                 9               9
#
#    Number-of-suppressed-rows  Min-weight  Max-weight  Total-weight  \
# 0                          0       30.00       48.00        108.00
# 1                          0        3.00       63.00        108.00
# 2                          0        0.01        2.56          5.11
# 3                          0        0.01        2.56          5.11
#
#    Sensitivity  Epsilon  Min-cell-size  Max-add-rows  Orig-rows  Lost-rows  \
# 0          0.0      0.0            0.0       1000000          3          0
# 1          0.0      0.0            0.0       1000000          4          0
# 2          0.0      0.0            0.0       1000000          9          0
# 3          0.0      0.0            0.0       1000000          9          0
#
#    Lost-rows%  Added-rows  Added-rows%  Final-rows  Final-rows%
# 0         0.0           0          0.0           3        100.0
# 1         0.0           0          0.0           4        100.0
# 2         0.0           0          0.0           9        100.0
# 3         0.0           0          0.0           9        100.0

# %% [markdown]
# ## Model specification report ##
#
# This shows how to manually create a model specification report.

# %%
from synthorus.workflows.report_spec import make_model_spec_report

make_model_spec_report(model_definition_dir)

# Show the report
print('-------------------------------------------')
print_file_tree(model_definition_dir / 'reports')
print('-------------------------------------------')
print()
cat(model_definition_dir / 'reports' / 'report_on_model_spec.txt')
# Out:
# -------------------------------------------
# reports/
#   crosstabs.csv
#   report_on_model_spec.txt
# -------------------------------------------
#
# Model Spec Report
# =================
#
# Report date: 2025-11-11 16:34:50 (+1100)
# Report author: user "barry"
#
# Model name: spec_simple_pjm
# Model author: Barry Drake
#
# Cross-tables:
#     Cross-table: _event_duration
#         Random variables: event_duration
#         Datasource: event_duration
#         Sensitivity: 0
#         Epsilon: 0
#         Min cell size: 0
#         State space size: 9
#         Number of rows: 9
#         Number of suppressed rows: 0
#         Min weight: 0.01
#         Max weight: 2.56
#         Total weight: 5.11
#
#     Cross-table: _event_duration_since_last
#         Random variables: event_duration_since_last
#         Datasource: event_duration_since_last
#         Sensitivity: 0
#         Epsilon: 0
#         Min cell size: 0
#         State space size: 9
#         Number of rows: 9
#         Number of suppressed rows: 0
#         Min weight: 0.01
#         Max weight: 2.56
#         Total weight: 5.11
#
#     Cross-table: _event_type
#         Random variables: event_type
#         Datasource: patient_age__event_type
#         Sensitivity: 0
#         Epsilon: 0
#         Min cell size: 0
#         State space size: 4
#         Number of rows: 4
#         Number of suppressed rows: 0
#         Min weight: 3
#         Max weight: 63
#         Total weight: 108
#
#     Cross-table: _patient_age
#         Random variables: patient_age
#         Datasource: patient_age__event_type
#         Sensitivity: 0
#         Epsilon: 0
#         Min cell size: 0
#         State space size: 3
#         Number of rows: 3
#         Number of suppressed rows: 0
#         Min weight: 30
#         Max weight: 48
#         Total weight: 108
#
# Summary:
#     No cross-table issues.
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Privacy report ##
#
# This shows how to manually create a privacy report.

# %%
from synthorus.workflows.report_privacy import make_privacy_report

make_privacy_report(model_definition_dir)

# Show the report
print('-------------------------------------------')
print_file_tree(model_definition_dir / 'reports')
print('-------------------------------------------')
print()
cat(model_definition_dir / 'reports' / 'report_on_privacy.txt')
# Out:
# -------------------------------------------
# reports/
#   crosstabs.csv
#   report_on_model_spec.txt
#   report_on_privacy.txt
# -------------------------------------------
#
# Privacy Report
# ==============
#
# Report date: 2025-11-11 16:34:50 (+1100)
# Report author: barry
#
# Model name: spec_simple_pjm
# Model author: Barry Drake
#
# Random number generator security level: 4 (equivalent to AES128 - adequate security)
# Privacy budget: 0 (no privacy risk)
#
# Datasources with zero sensitivity (3 of 3):
#     event_duration
#     event_duration_since_last
#     patient_age__event_type
#
# Datasources (3):
#     Datasource name: event_duration
#     Sensitivity: 0
#     Random variables: event_duration
#     Distinct rows: 9
#     Total weight: 5.11
#     Entropy: 1.9795669564757818
#
#     Datasource name: event_duration_since_last
#     Sensitivity: 0
#     Random variables: event_duration_since_last
#     Distinct rows: 9
#     Total weight: 5.11
#     Entropy: 1.979566956475782
#
#     Datasource name: patient_age__event_type
#     Sensitivity: 0
#     Random variables: patient_age, event_type
#     Distinct rows: 7
#     Total weight: 108
#     Entropy: 2.5175932387933115
#
# Cross-tables (4):
#     Random variables: event_duration
#     State space size: 9
#     Datasource: event_duration
#     Sensitivity: 0
#     Epsilon: 0.1
#     Min cell size: 0
#     Distinct rows: 9
#     Total weight: 5.11
#     Entropy: 1.9795669564757818
#
#     Random variables: event_duration_since_last
#     State space size: 9
#     Datasource: event_duration_since_last
#     Sensitivity: 0
#     Epsilon: 0.1
#     Min cell size: 0
#     Distinct rows: 9
#     Total weight: 5.11
#     Entropy: 1.979566956475782
#
#     Random variables: event_type
#     State space size: 4
#     Datasource: patient_age__event_type
#     Sensitivity: 0
#     Epsilon: 0.1
#     Min cell size: 0
#     Distinct rows: 7
#     Total weight: 108
#     Entropy: 2.5175932387933115
#
#     Random variables: patient_age
#     State space size: 3
#     Datasource: patient_age__event_type
#     Sensitivity: 0
#     Epsilon: 0.1
#     Min cell size: 0
#     Distinct rows: 7
#     Total weight: 108
#     Entropy: 2.5175932387933115
#
# Random variables (4:
#     Random variable name: 'event_duration'
#     Primary datasource: 'event_duration'
#     Number of values: 9
#     Number of support values: 9
#     Values: 1, 2, 3, 4, 5, 6, 7, 8, 9
#     Total weight: 5.109999999999999
#     Entropy: 1.9795669564757818
#     Distribution: 1 = 0.501, 2 = 0.2505, 3 = 0.1252, 4 = 0.06262, 5 = 0.03131, 6 = 0.01566, 7 = 0.007828, 8 = 0.003914, 9 = 0.001957
#
#     Random variable name: 'event_duration_since_last'
#     Primary datasource: 'event_duration_since_last'
#     Number of values: 9
#     Number of support values: 9
#     Values: 1, 2, 3, 4, 5, 6, 7, 8, 9
#     Total weight: 5.109999999999999
#     Entropy: 1.979566956475782
#     Distribution: 1 = 0.001957, 2 = 0.003914, 3 = 0.007828, 4 = 0.01566, 5 = 0.03131, 6 = 0.06262, 7 = 0.1252, 8 = 0.2505, 9 = 0.501
#
#     Random variable name: 'event_type'
#     Primary datasource: 'patient_age__event_type'
#     Number of values: 4
#     Number of support values: 4
#     Values: AP, DEATH, ED, GP
#     Total weight: 108
#     Entropy: 1.4186110796220983
#     Distribution: AP = 0.08333, DEATH = 0.02778, ED = 0.3056, GP = 0.5833
#
#     Random variable name: 'patient_age'
#     Primary datasource: 'patient_age__event_type'
#     Number of values: 3
#     Number of support values: 3
#     Values: middle_aged, old, young
#     Total weight: 108
#     Entropy: 1.5466316153937778
#     Distribution: middle_aged = 0.4444, old = 0.2778, young = 0.2778
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Utility report ##
#
# This shows how to create a utility report.

# %%
from synthorus.workflows.report_utility import make_utility_report

make_utility_report(model_definition_dir)

# Show the report
print('-------------------------------------------')
print_file_tree(model_definition_dir / 'reports')
print('-------------------------------------------')
print()
cat(model_definition_dir / 'reports' / 'report_on_utility.txt')
# Out:
# generating report on utility
# entity: patient
# loading PGM
# compiling PGM
# constructing evaluation trials
# entity: event
# loading PGM
# compiling PGM
# constructing evaluation trials
# running evaluation trials
# trial 1 of 8, event HI event_duration: 0.0
# trial 2 of 8, event KL event_duration: 1.0
# trial 3 of 8, event HI event_duration_since_last: 0.0
# trial 4 of 8, event KL event_duration_since_last: 1.0
# trial 5 of 8, event HI event_type: 0.0
# trial 6 of 8, event KL event_type: 1.0
# trial 7 of 8, patient HI patient_age: 0.0
# trial 8 of 8, patient KL patient_age: 1.0
# -------------------------------------------
# reports/
#   crosstabs.csv
#   report_on_model_spec.txt
#   report_on_privacy.txt
#   report_on_utility.txt
#   utility_results.csv
# -------------------------------------------
#
# Utility Report
# ==============
#
# Report date: 2025-11-11 16:34:50 (+1100)
# Report author: user "barry"
#
# Model name: spec_simple_pjm
# Model author: Barry Drake
#
# Analysis summary:
#
#     Number of entities: 2
#
#     Entity: event
#         Worst histogram-intersection overall: 0.00%
#             random variable set: {event_duration}
#             random variable set: {event_duration_since_last}
#             random variable set: {event_type}
#
#     Entity: patient
#         Worst histogram-intersection overall: 0.00%
#             random variable set: {patient_age}
#
# --------------------------------------------------------------------------------

# %% [markdown]
# And here are the detailed utility results.

# %%
pd.read_csv(model_definition_dir / 'reports' / 'utility_results.csv')
# Out:
#     entity  number_of_rvs                        rvs            measure_name  \
# 0    event              1             event_duration  histogram-intersection
# 1    event              1             event_duration           KL-divergence
# 2    event              1  event_duration_since_last  histogram-intersection
# 3    event              1  event_duration_since_last           KL-divergence
# 4    event              1                 event_type  histogram-intersection
# 5    event              1                 event_type           KL-divergence
# 6  patient              1                patient_age  histogram-intersection
# 7  patient              1                patient_age           KL-divergence
#
#    measurement
# 0          0.0
# 1          1.0
# 2          0.0
# 3          1.0
# 4          0.0
# 5          1.0
# 6          0.0
# 7          1.0

# %%
# Perform any cleanup operations of the managed demo output directory.
model_definition_dir.cleanup()
