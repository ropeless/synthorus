# %% [markdown]
# (notebook-synthorus-workflows)=
# # Synthorus Workflows #
#
# This section provides a brief overview of the workflows for generating synthetic data.
# The remaining sections explain the components of the workflows.
#
# There are three main workflows when using Synthorus. These are:
# 1. make a model
# 2. make and run a simulator
# 3. make reports.
#
# These are shown schematically in the following figure.
#
# ```{figure} figures/synthorus_high_level_workflows.svg
# ---
# scale: 50%
# align: center
# name: synthorus_high_level_workflows
# ---
# A schematic diagram showing a high-level view of Synthorus workflows.
# ```
#
#
# ## Making a Model ##
#
# Making a model involves providing a model specification. A model specification describes:
# - model meta-data
# - privacy protection and other parameter values
# - datasources for reference data
# - what are the random variables and their states
# - what are the cross-tables
# - what are the entities, their fields, and their relationships
# - simulation parameters and values.
#
# The steps to make a model are as follows. These steps are performed using the `make_model_definition_files` function.
# 1. Datasets specified in the model specification will be loaded based on the specified datasources.
# 2. Clean cross-tables are computed.
# 3. Privacy protection is applied to create noisy cross-tables.
# 4. The noisy cross-tables are used to create a probabilistic graphical model (PGM) for each entity.
# 5. A simulator specification is formed which describes the model entities and how to generate records for entities.
#
# The result of making a model is a collection of files which are placed into a model definition folder. The files are:
# 1. a JSON definition of the model ('model_spec.json')
# 2. a JSON definition of an index for model components ('model_index.json')
# 3. a JSON definition of model metadata ('model_meta.json')
# 4. a JSON definition of the synthetic data simulator ('simulator_spec.json')
# 5. noisy cross-tables ('noisy_cross_tables/{_cross_table_}.pk')
# 6. clean cross-tables ('clean_cross_tables/{_cross_table_}.pk')
# 7. Compiled Knowledge PGMs for each entity ('pgms/{_entity_}.py')
#
# In the given filenames, {_entity_} and {_cross_table_} are the names of an entity and cross-table respectively, as referenced by the JSON files.
#
# ### ModelSpec ###
#
# The core data structure for specifying a Synthorus system is an object of class `ModelSpec`.
# A `ModelSpec` is a Pydantic object so can be created either programmatically or by reading a JSON description.
#
# The `ModelSpec` representation is described on page [ModelSpec](#notebook-model-spec).
#
# ### Spec File ###
#
# It is possible to manually construct a `ModelSpec` object or its equivalent JSON. However, it can be tedious for all but trivial Synthorus systems.
#  A more human-friendly option to specify a Synthorus system is to use a "spec file".
#
# A spec file is Python code that defines a spec file dictionary. This is a very flexible format as any valid Python code is permitted.
# This means that loading a spec file has full access to your Python environment.
#
# Sharing or using a spec file should be treated in the same way as sharing or using Python code.
# Only use a spec file if you trust the source.
# A safe way to share a Synthorus specification is to convert a spec file to a `ModelSpec` object and share the serialized JSON.
#
# For details on spec files, see the page [Spec File](notebook-spec-file).
#
# ## Making and Running a Simulator ##
#
# A simulator is a Python object of class `Simulator`. A Simulator object can be constructed from files in a model definition folder. Essentially, making the `Simulator` object involves:
# 1. loading a PGM for each entity
# 2. loading the simulator specification file
# 3. constructing and configuring a `Simulator` object.
#
# When a simulator is run, it needs to know what to do with the generated records. This is described by a `SimRecorder` object. `SimRecorder` is an abstract base class – Synthorus provides several concreate implementations. For example, a simple `SimRecorder` can be created by constructing a `DebugRecorder`. A `DebugRecorder` just writes records to stdout (or file) as the records are generated.
#
# A simulator can be run by calling method `run` on a `Simulator` object. Method `run` is given a `SimRecorder` object and optionally can be given the number of iterations to run the simulation.
#
# For details on simulators, see the page [Simulators](notebook-simulators).
#
#
# ## Making Reports ##
#
# Synthorus provides reports on a synthetic data system. These reports are:
# 1. a system specification report ('report_on_model_spec.html')
# 2. a cross-table report ('crosstabs.csv')
# 3. a privacy report ('report_on_privacy.txt')
# 4. a utility report ('report_on_utility.txt')
# 5. detailed utility results ('utility_results.csv')
#
# The report filename is shown in brackets. These files are placed in a `reports` directory that is a subdirectory of the model definition folder.
#
# Most of these reports are computationally cheap and are created as a by-product of making a model (specifically, 1, 2, and 3). The other two reports (4 and 5) are potentially computationally expensive, so are designed to run using a separate script.
#
# For details on reports, see the page [Simulators](notebook-reports).

# %% [markdown]
# ## Workflow Demonstration ##

# %% [markdown]
# ### Demo Output Directory ###
#
# The example code below needs to write files to a model definition folder. We use a managed demo output directory for this. The following code snippet gives access to a managed demo output directory.
# ```
# from synthorus_demos.utils.output_directory import output_directory
#
# with output_directory('my_directory') as my_dir:
#     ...
# ```
#
# Code within the `with` context will have access to an empty directory named "my_directory", available as a `Path` object `my_dir`. The directory "my_directory" will be created empty as a subdirectory of the _demo_out_ directory. The _demo_out_ directory is configured using the local configuration variable "DEMO_OUT". If "DEMO_OUT" is not defined, a temporary directory is created using `tempfile`.
#
# IMPORTANT, `output_directory` is only needed to run these demonstrations. It is unnecessary for normal usage of Synthorus.
#
# The following shows how to use `output_directory` to create a managed output directory.

# %%
from synthorus_demos.utils.output_directory import output_directory
from synthorus.utils.config_help import config

print(config.DEMO_OUT)

with output_directory('my_directory') as my_dir:
    print(my_dir)
# Out:
# C:/Users/barry/Development/synthorus/out
# C:\Users\barry\Development\synthorus\out\my_directory

# %% [markdown]
# The following example reads the spec file `spec_tiny.py` in `synthorus_demos.demo_files.spec_files` and uses `load_spec_file` to create a `ModelSpec`.

# %% [markdown]
# ### Tiny Demo ###
#
# This workflow demonstration will use the "spec_tiny.py" spec file.

# %%
from synthorus_demos.utils.file_helper import cat
from synthorus_demos.demo_files import SPEC_FILES

spec_file = SPEC_FILES / 'spec_tiny.py'  # `SPEC_FILES` is the directory containing all the demo spec files.

cat(spec_file)  # `cat` is just like unix cat, i.e., prints the contents of a file given the file name.
# Out:
# """
# This is an example simple Synthorus spec file.
# """
# from synthorus.spec_file.keys import *
#
# spec = {
#     states: infer_distinct,  # all random variable states are inferred from the datasource.
#
#     datasources: {
#         'xyz': {
#             data_format: csv,
#             inline: """
#                 X,Y,Z
#                 y,y,y
#                 y,y,n
#                 y,n,y
#                 y,n,n
#                 n,y,y
#                 n,y,n
#                 n,n,y
#                 n,n,n
#                 """
#         }
#     }
# }

# %% [markdown]
# The following code loads the spec file, converts it to a `ModelSpec` then prints its JSON representation.

# %%
from synthorus.spec_file.interpret_spec_file import load_spec_file
from synthorus.model.model_spec import ModelSpec

model_spec: ModelSpec = load_spec_file(spec_file)

# Render model spec as JSON, printing to stdout.
print(model_spec.model_dump_json(indent=2))
# Out:
# {
#   "name": "spec_tiny",
#   "author": "_unknown_",
#   "comment": "This is an example simple Synthorus spec file.",
#   "roots": [],
#   "rng_n": 4,
#   "pgm_crosstabs": "noisy",
#   "datasources": {
#     "xyz": {
#       "sensitivity": 0.0,
#       "rvs": [
#         "X",
#         "Y",
#         "Z"
#       ],
#       "dataset_spec": {
#         "type": "csv",
#         "weight": null,
#         "rv_map": null,
#         "rv_define": {},
#         "input": {
#           "type": "inline",
#           "inline": "X,Y,Z\ny,y,y\ny,y,n\ny,n,y\ny,n,n\nn,y,y\nn,y,n\nn,n,y\nn,n,n\n"
#         },
#         "sep": ",",
#         "header": true,
#         "skip_blank_lines": true,
#         "skip_initial_space": true
#       },
#       "non_distribution_rvs": []
#     }
#   },
#   "rvs": {
#     "X": {
#       "states": "infer_distinct",
#       "ensure_none": false
#     },
#     "Y": {
#       "states": "infer_distinct",
#       "ensure_none": false
#     },
#     "Z": {
# ...

# %% [markdown]
# This spec file defines one datasource, "xyz" that includes three random variables, "X", "Y" and "Z".
#
# System random variables can be explicitly defined in a spec file using the "rvs" section. The demo `spec_tiny.py` does not include that section, so one is internally created with a random variable defined for each random variable seen in any datasource. Each random variable definition needs to define the possible states of the random variable. Including `states: infer_distinct` at the top level of a spec file dictionary means that `states: infer_distinct` will be inherited for every random variable definition. The value `infer_distinct` means that the possible values of a random variable will be defined as "all distinct values seen for that random variable in the datasources."

# %% [markdown]
# Synthorus provides a function `make_model_definition_files` for taking a model spec and creating model definition files.
#
# The following code demonstrates this using `model_spec` define above.

# %%
from synthorus.utils.print_function import NO_LOG
from synthorus_demos.utils.file_helper import print_file_tree
from synthorus.workflows.make_model_definition_files import make_model_definition_files

with output_directory('my_model_definition_files', overwrite=True) as model_definition_dir:

    make_model_definition_files(model_spec, model_definition_dir, log=NO_LOG)

    # Show what files got created
    print('-------------------------------------------')
    print_file_tree(model_definition_dir)
    print('-------------------------------------------')
# Out:
# -------------------------------------------
# my_model_definition_files/
#   clean_cross_tables/
#     _X_.pkl
#     _Y_.pkl
#     _Z_.pkl
#   model_index.json
#   model_meta.json
#   model_spec.json
#   noisy_cross_tables/
#     _X_.pkl
#     _Y_.pkl
#     _Z_.pkl
#   pgms/
#     _default_entity_.py
#   reports/
#     crosstabs.csv
#     report_on_model_spec.html
#     report_on_privacy.txt
#   simulator_spec.json
# -------------------------------------------

# %% [markdown]
# Here are links to selected output files, including some standard reports.
# * {download}`report_on_model_spec.html <output_directory/my_model_definition_files/reports/report_on_model_spec.html>`
# * {download}`report_on_privacy.txt <output_directory/my_model_definition_files/reports/report_on_privacy.txt>`
# * {download}`crosstabs.csv <output_directory/my_model_definition_files/reports/crosstabs.csv>`
# * {download}`model_spec.json <output_directory/my_model_definition_files/model_spec.json>`
# * {download}`model_index.json <output_directory/my_model_definition_files/model_index.json>`
# * {download}`model_meta.json <output_directory/my_model_definition_files/model_meta.json>`
# * {download}`simulator_spec.json <output_directory/my_model_definition_files/simulator_spec.json>`

# %% [markdown]
# A simulator can be constructed and run using the resulting model definition files. The following code shows how.

# %%
from synthorus.simulator.sim_recorder import DebugRecorder
from synthorus.simulator.simulator import Simulator
from synthorus.workflows.make_simulator_from_files import make_simulator_from_files

with output_directory('my_model_definition_files', overwrite=True) as model_definition_dir:

    make_model_definition_files(model_spec, model_definition_dir, log=NO_LOG)
    simulator: Simulator = make_simulator_from_files(model_definition_dir, log=NO_LOG)

simulator.run(DebugRecorder(), iterations=8)
# Out:
# Entity: _default_entity_ ['_id_', '_count_', 'X', 'Y', 'Z']
#
# _default_entity_ [('_id_', 1), ('_count_', 1), ('X', 'y'), ('Y', 'n'), ('Z', 'y')]
# _default_entity_ [('_id_', 2), ('_count_', 1), ('X', 'y'), ('Y', 'n'), ('Z', 'y')]
# _default_entity_ [('_id_', 3), ('_count_', 1), ('X', 'n'), ('Y', 'n'), ('Z', 'n')]
# _default_entity_ [('_id_', 4), ('_count_', 1), ('X', 'n'), ('Y', 'y'), ('Z', 'n')]
# _default_entity_ [('_id_', 5), ('_count_', 1), ('X', 'y'), ('Y', 'n'), ('Z', 'y')]
# _default_entity_ [('_id_', 6), ('_count_', 1), ('X', 'n'), ('Y', 'y'), ('Z', 'y')]
# _default_entity_ [('_id_', 7), ('_count_', 1), ('X', 'y'), ('Y', 'y'), ('Z', 'n')]
# _default_entity_ [('_id_', 8), ('_count_', 1), ('X', 'y'), ('Y', 'y'), ('Z', 'n')]
#
# Finished
