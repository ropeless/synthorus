# %% [markdown]
# # Introduction

# %% [markdown]
# ## What is Synthorus
#
# Synthorus is a software library for ....
#
# The library is provided as a Python package (called `synthorus`).
#
# ### Aim
#
# The main aim of Synthorus is to provide ...
#
# ### Key features
#
# Synthorus provides ...
